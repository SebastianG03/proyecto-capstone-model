# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
print(torch.__version__)
# Out:
# 2.9.1+cpu

# %%
  # debe contener «nightly» y «cu126»
print(torch.cuda.get_device_name(0))
print(torch.cuda.get_device_capability())  # (12, 0)
print(torch.cuda.is_available())
# Out:
# 2.9.1+cpu
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 print(torch.__version__)          # debe contener «nightly» y «cu126»
# ----> 2 print(torch.cuda.get_device_name(0))
#       3 print(torch.cuda.get_device_capability())  # (12, 0)
#       4 print(torch.cuda.is_available())
#
# File c:\Users\Usuario\Desktop\projects\proyecto-capstone-model\.venv\Lib\site-packages\torch\cuda\__init__.py:582, in get_device_name(device)
#     570 def get_device_name(device: "Device" = None) -> str:
#     571     r"""Get the name of a device.
#     572
#     573     Args:
#    (...)    580         str: the name of the device
#     581     """
# --> 582     return get_device_properties(device).name
#
# File c:\Users\Usuario\Desktop\projects\proyecto-capstone-model\.venv\Lib\site-packages\torch\cuda\__init__.py:614, in get_device_properties(device)
# ...
